# %%
from matplotlib import pyplot as plt

X=[2,4,6]
Y=[1,3,9]

plt.plot(X,Y,'ko--')
plt.show()

# %%
import matplotlib.pyplot as plt
x=[0,1,2,3,4,5]
y1=[0, 1, 4, 9, 16, 25]
y2=[0,1,8,27,64,125]

plt.plot(x,y1,marker='o',linestyle='--',color='b',label='y=x^2')
plt.plot(x,y2,marker='o', linestyle='--',color='k',label='y= x^3')

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Line Plot')

plt.legend()
plt.grid(True,c='k')
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
import numpy as np
x=np.random.randint(100,size=100)
x
# Out:
# array([26, 85,  7, 40, 10, 71, 63, 84, 53, 85, 38, 13, 59,  3, 32, 51, 58,
#        81, 73, 22, 24, 10, 98, 22, 17,  6,  5, 24, 33, 23, 17, 73, 14,  4,
#        36, 45, 38, 30, 89, 81, 32, 78, 97, 36, 51, 47, 76, 68, 62, 20, 72,
#        73, 47,  5, 78, 33, 34, 79, 19, 40, 86, 83,  5, 16, 62, 12, 76,  0,
#         2, 56,  8, 50, 68, 19, 34, 56, 42, 50, 83, 56, 14, 48,  3, 64, 70,
#        28, 46, 78, 64, 92, 67, 27, 14, 18, 58, 24, 20, 47, 94, 17],
#       dtype=int32)

# %%
import numpy as np
x=np.random.randint(100,size=100)
y=np.random.randint(100,size=100)
plt.scatter(x,y,marker='o',s=30)

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title("Scatter Plot")
plt.show()

# %% [markdown]
# # Histogram

# %%
x=np.random.normal(20,1,100)
print(x)
# Out:
# [19.85817685 19.47989727 19.23963977 20.52368275 19.14666328 21.25081335
#  21.28305995 19.56954377 21.45462433 19.78392276 20.63749099 19.62692327
#  19.92929906 19.14543038 18.9155207  18.97274702 20.89992636 20.86186008
#  20.39316449 18.79160572 19.72818691 18.6966203  19.17006298 19.72868048
#  17.86662166 21.6399916  19.92865941 19.71231317 20.14027436 19.50886754
#  21.19587734 18.5532557  19.59321847 20.25955184 19.60052076 20.22338427
#  20.71605503 18.32984139 19.35588722 19.4432649  20.40513226 20.81558995
#  20.02777152 18.80811428 20.80784092 19.29718541 19.86345657 20.41706711
#  18.6379636  20.9164013  20.49271152 20.28678633 19.91616363 18.91457702
#  21.80411424 21.60767211 18.03603648 22.10565878 19.3586953  20.05715126
#  18.95532375 19.41956212 18.36742385 21.47065341 21.15952328 17.31469096
#  20.50132929 20.29247518 20.89575569 20.26814934 19.13229656 22.14840959
#  19.73669345 20.14555528 20.37057315 19.61605507 20.25571968 17.83208063
#  20.74667243 19.57320485 19.49646537 19.9316722  18.1491205  21.26709753
#  20.4364117  21.5646567  18.03653072 21.43871591 20.6024864  21.8405958
#  19.39662325 19.35628905 20.4256737  22.21594426 20.36545344 19.47968252
#  18.18310395 19.34171934 20.9287624  21.82660693]

# %%
x=np.random.normal(20,5,1000)
plt.hist(x,bins=13)
plt.title('Histogram' ,fontsize=25)
plt.show()

# %% [markdown]
# # Bar Chart

# %%
import matplotlib.pyplot as plt
categories= ['A','B','C','D']
values=np.random.randint(100,size=4)

plt.bar(categories ,values,color='skyblue' ,width=0.5)

plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Chart')

plt.show()

# %% [markdown]
# # Pie Chart

# %%
import matplotlib.pyplot as plt
categories=['A','B','C']
values=np.random.randint(100,size=3)

plt.pie(values,labels=categories, explode=[0,0.1,0],autopct="%.1f%%",startangle=90,shadow=True)
plt.title("Pie Chart")
plt.show()

# %% [markdown]
# # Box Plot

# %%
import matplotlib.pyplot as plt
x=np.random.normal(200,8,1000)

IQR=np.quantile(x,0.75) -np.quantile(x,0.25)
print('Lower Fence : ', np.quantile(x, 0.25)-(1.5*IQR))
print('Q1 : ',np.quantile(x, 0.25))
print('Median : ',np.median(x))
print('Q3 : ',np.quantile(x, 0.75))
print('Upper Fence : ',np.quantile(x, 0.75)+(1.5*IQR))
print('\n')

plt.boxplot(x) 
plt.title('BOX Plot')
plt.yticks([np.quantile(x,0.25) -(1.5 *IQR) ,np.quantile(x,0.25),np.median(x),np.quantile(x, 0.75),np.quantile(x, 0.75)+(1.5*IQR)])
plt.show()
# Out:
# Lower Fence :  178.6072471266199
# Q1 :  194.7288269019453
# Median :  200.0501741965744
# Q3 :  205.47654675216222
# Upper Fence :  221.5981265274876

# %% [markdown]
# # SubPloting

# %%
x=np.arange(100)
P1=np.sin(x)
P2=np.cos(x)

plt.subplot(221)
plt.plot(P1)
plt.title("sine function")

plt.subplot(222)
plt.plot(P2)
plt.title('cosine function')

plt.show()

# %%
#spliting the figure into subparts
fig , axis = plt.subplots(2,2)

# Plotting through axis
axis[0, 0].plot(np.sin(np.arange(100)))
axis[0, 1].hist(np.random.normal(20,5,1000))
axis[1, 0].bar(categories, values)
axis[1, 1].plot(np.log(np.arange(100)))

# Display the plots
plt.show()
# Out:
# C:\Users\NEHA\AppData\Local\Temp\ipykernel_25420\1602228888.py:8: RuntimeWarning: divide by zero encountered in log
#   axis[1, 1].plot(np.log(np.arange(100)))

# %% [markdown]
# # 3D Plotting

# %%
import numpy as np
import matplotlib.pyplot as plt
ax=plt.axes(projection='3d')
X=np.random.randint(100,size=100)
Y=np.random.randint(100,size=100)
Z=np.random.randint(100,size=100)

ax.scatter(X,Y,Z)
plt.show()

# %% [markdown]
# # Animating the plots

# %%
import numpy as np
import matplotlib.pyplot as plt

n_tosses=100
heads_count=0
tosses=np.arange(1,n_tosses+1)

fig,ax=plt.subplots()
ax.set_xlim(1,n_tosses)
ax.set_ylim(0,1)
line, =ax.plot([],[],color='black')

ax.set_xlabel("No. of tosses")
ax.set_ylabel("Proportion of heads")
ax.set_title("Coin Toss simulation")

proportions_heads=[]
for i in range(1,n_tosses +1):
    toss=np.random.randint(0,2)
    if toss==1:
        heads_count+=1

    proportions_heads.append(heads_count / i)

    line.set_data(tosses[:i],proportions_heads)

    # plt.pause(0.01)

plt.show()
