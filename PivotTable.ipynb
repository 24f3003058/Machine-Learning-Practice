# %% [markdown]
# # Pivot Table

# %%
import pandas as pd 
import numpy as np

# %%
data = {
    'Date': ['2022-01-01', '2022-01-01', '2022-01-02', '2022-01-02'],
    'Category': ['A', 'B', 'A', 'B'],
    'Value': [10, 20, 30, 40]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#          Date Category  Value
# 0  2022-01-01        A     10
# 1  2022-01-01        B     20
# 2  2022-01-02        A     30
# 3  2022-01-02        B     40

# %%
# Create a pivot table
pivot_table=df.pivot_table(values='Value',index='Date',columns='Category',aggfunc='sum')
pivot_table
# Out:
# Category     A   B
# Date
# 2022-01-01  10  20
# 2022-01-02  30  40

# %%
data={}
np.random.seed(2)
for i in [chr(x) for x in range(65,70)]:
    data['col' + i] =np.random.randint(1,100,10)
data['orderID'] =np.random.choice(['A','B','C'],10)
data['product']=np.random.choice(['Product1','Product2','Product3'],10)
data['customer']=np.random.choice(['Customer1','Customer2','Customer3','Customer4'],10)
df=pd.DataFrame(data)
df
# Out:
#    colA  colB  colC  colD  colE orderID   product   customer
# 0    41    96    68    69    51       B  Product2  Customer3
# 1    16    76     5    47     5       C  Product2  Customer1
# 2    73    86    43    71    91       B  Product2  Customer1
# 3    23    48    52    96    64       B  Product3  Customer3
# 4    44    64    39    84    80       A  Product1  Customer3
# 5    83    32    34    32    50       B  Product3  Customer1
# 6    76    91    59    67    40       C  Product3  Customer3
# 7     8    21    68    81    47       A  Product1  Customer1
# 8    35    38    70    53     9       C  Product1  Customer2
# 9    50    40    89    77    51       B  Product3  Customer3

# %%
pivot_table1=df.pivot_table(values='colA',columns='product',index='orderID',aggfunc=np.mean)
print(pivot_table1.to_string())
# Out:
# product  Product1  Product2  Product3
# orderID
# A            26.0       NaN       NaN
# B             NaN      57.0      52.0
# C            35.0      16.0      76.0
# C:\Users\NEHA\AppData\Local\Temp\ipykernel_29240\521650249.py:1: FutureWarning: The provided callable <function mean at 0x000001FC7F413CE0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot_table1=df.pivot_table(values='colA',columns='product',index='orderID',aggfunc=np.mean)

# %% [markdown]
# # Operations with Pivot table

# %%
pivot_table3=df.pivot_table(values='colA',index='orderID' ,columns='product',aggfunc='max')
pivot_table3
# Out:
# product  Product1  Product2  Product3
# orderID
# A            44.0       NaN       NaN
# B             NaN      73.0      83.0
# C            35.0      16.0      76.0

# %%
df
# Out:
#    colA  colB  colC  colD  colE orderID   product   customer
# 0    41    96    68    69    51       B  Product2  Customer3
# 1    16    76     5    47     5       C  Product2  Customer1
# 2    73    86    43    71    91       B  Product2  Customer1
# 3    23    48    52    96    64       B  Product3  Customer3
# 4    44    64    39    84    80       A  Product1  Customer3
# 5    83    32    34    32    50       B  Product3  Customer1
# 6    76    91    59    67    40       C  Product3  Customer3
# 7     8    21    68    81    47       A  Product1  Customer1
# 8    35    38    70    53     9       C  Product1  Customer2
# 9    50    40    89    77    51       B  Product3  Customer3

# %% [markdown]
# # Multi-level Pivot Tables

# %%
pivot_table=df.pivot_table(values='Value' ,index=['Date', 'Category'], aggfunc='sum')
pivot_table
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 pivot_table=df.pivot_table(values='Value' ,index=['Date', 'Category'], aggfunc='sum')
#       2 pivot_table
#
# File c:\Langchain\venv\Lib\site-packages\pandas\core\frame.py:9516, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9499 @Substitution("")
#    9500 @Appender(_shared_docs["pivot_table"])
#    9501 def pivot_table(
#    (...)   9512     sort: bool = True,
#    9513 ) -> DataFrame:
#    9514     from pandas.core.reshape.pivot import pivot_table
# -> 9516     return pivot_table(
#    9517         self,
#    9518         values=values,
#    9519         index=index,
#    9520         columns=columns,
#    9521         aggfunc=aggfunc,
#    9522         fill_value=fill_value,
#    9523         margins=margins,
#    9524         dropna=dropna,
#    9525         margins_name=margins_name,
#    9526         observed=observed,
#    9527         sort=sort,
#    9528     )
#
# File c:\Langchain\venv\Lib\site-packages\pandas\core\reshape\pivot.py:102, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      99     table = concat(pieces, keys=keys, axis=1)
#     100     return table.__finalize__(data, method="pivot_table")
# --> 102 table = __internal_pivot_table(
#     103     data,
#     104     values,
#     105     index,
#     106     columns,
#     107     aggfunc,
#     108     fill_value,
#     109     margins,
#     110     dropna,
#     111     margins_name,
#     112     observed,
#     113     sort,
#     114 )
#     115 return table.__finalize__(data, method="pivot_table")
#
# File c:\Langchain\venv\Lib\site-packages\pandas\core\reshape\pivot.py:148, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     146 for i in values:
#     147     if i not in data:
# --> 148         raise KeyError(i)
#     150 to_filter = []
#     151 for x in keys + values:
#
# KeyError: 'Value'

# %%
pivot_table4=df.pivot_table(values='colA', index=['orderID','customer'], columns='product',aggfunc='max')
pivot_table4
# Out:
# product            Product1  Product2  Product3
# orderID customer
# A       Customer1       8.0       NaN       NaN
#         Customer3      44.0       NaN       NaN
# B       Customer1       NaN      73.0      83.0
#         Customer3       NaN      41.0      50.0
# C       Customer1       NaN      16.0       NaN
#         Customer2      35.0       NaN       NaN
#         Customer3       NaN       NaN      76.0

# %%
pivot_table5 = df.pivot_table(values='colA', index='orderID', columns='product', aggfunc=np.mean, fill_value=0)
pivot_table5
# Out:
# C:\Users\NEHA\AppData\Local\Temp\ipykernel_29240\2778420001.py:1: FutureWarning: The provided callable <function mean at 0x000001FC7F413CE0> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   pivot_table5 = df.pivot_table(values='colA', index='orderID', columns='product', aggfunc=np.mean, fill_value=0)
# product  Product1  Product2  Product3
# orderID
# A            26.0       0.0       0.0
# B             0.0      57.0      52.0
# C            35.0      16.0      76.0

# %%
pivot_table6 = df.pivot_table(values='colA', index=['orderID','customer'], columns='product', aggfunc='max', fill_value = 0)
pivot_table6
# Out:
# product            Product1  Product2  Product3
# orderID customer
# A       Customer1         8         0         0
#         Customer3        44         0         0
# B       Customer1         0        73        83
#         Customer3         0        41        50
# C       Customer1         0        16         0
#         Customer2        35         0         0
#         Customer3         0         0        76
